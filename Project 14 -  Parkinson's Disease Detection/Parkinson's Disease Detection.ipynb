# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
dis_data = pd.read_csv("parkinsons.csv")

# %%
dis_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread1   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302        74.997  ... -4.813031  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650       113.819  ... -4.075192  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111       111.555  ... -4.443179  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871       111.366  ... -4.117501  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781       110.655  ... -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
dis_data.shape
# Out:
# (195, 24)

# %%
dis_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
dis_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
dis_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...     spread1     spread2          D2         PPE
# count   195.000000    195.000000    195.000000      195.000000  ...  195.000000  195.000000  195.000000  195.000000
# mean    154.228641    197.104918    116.324631        0.006220  ...   -5.684397    0.226510    2.381826    0.206552
# std      41.390065     91.491548     43.521413        0.004848  ...    1.090208    0.083406    0.382799    0.090119
# min      88.333000    102.145000     65.476000        0.001680  ...   -7.964984    0.006274    1.423287    0.044539
# 25%     117.572000    134.862500     84.291000        0.003460  ...   -6.450096    0.174351    2.099125    0.137451
# 50%     148.790000    175.829000    104.315000        0.004940  ...   -5.720868    0.218885    2.361532    0.194052
# 75%     182.769000    224.205500    140.018500        0.007365  ...   -5.046192    0.279234    2.636456    0.252980
# ...

# %%
#distribution of target variable(status)
dis_data['status'].value_counts()
# 0 - posititve
# 1 - negative
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
#grouping the data based on the target variable 

numeric_cols = dis_data.select_dtypes(include=['number'])

# Group by 'status' and calculate mean
grouped_mean = numeric_cols.groupby(dis_data['status']).mean()

# %%
print(grouped_mean)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# status                                                           ...
# 0        181.937771    223.636750    145.207292        0.003866  ... -6.759264  0.160292  2.154491  0.123017
# 1        145.180762    188.441463    106.893558        0.006989  ... -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 23 columns]

# %%
#data preprocessing
#Seperating the features and target
x = dis_data.drop(columns=['name','status'],axis=1)
y = dis_data['status']

# %%
#splitting thedata to training and test data
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
#data standardization
scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
print(x_train)
# Out:
# [[-0.80172872 -0.70830513 -0.10603303 ...  0.89854281 -0.48294197
#    1.64980971]
#  [-1.04374224 -0.74950432 -0.29919921 ...  1.17531845  0.65177741
#    0.26864313]
#  [-0.3790498   0.13122544 -0.82039362 ... -0.7771489  -0.73102398
#    0.28542547]
#  ...
#  [-0.13744368 -0.31583967  0.56292775 ... -1.65126173 -0.08248373
#   -0.17764131]
#  [-0.14053505 -0.42034011  0.39263744 ...  0.19569946  1.19665768
#   -0.11105606]
#  [-0.35427092  4.57536567 -1.22354854 ...  0.55494177  0.80279984
#    2.57800238]]

# %%
#model training
#Support vector machine model(svm)

# %%
model = svm.SVC(kernel='linear')
#training the model
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#model evaluation
#Accuracy score
#training data
x_train_pre = model.predict(x_train)
train_data_ac = accuracy_score(x_train_pre,y_train)
print(train_data_ac)
# Out:
# 0.9038461538461539

# %%
#test data accuracy
test_data_pre = model.predict(x_test)
test_data_ac = accuracy_score(test_data_pre,y_test)
print(test_data_ac)
# Out:
# 0.1794871794871795
